# %%
import pandas as pd

# %% [markdown]
# **Data Collection**

# %%
df =pd.read_csv("/content/hotel_bookings.csv")
print(df)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# **Data Preprocessing**

# %%
#checking for missing values in the dataset
missing_data= df.isnull().sum()
print(missing_data)
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#dropping columns
df.drop('company',inplace=True,axis=1)
df.drop('arrival_date_week_number',inplace=True,axis=1)

# %%
#Filling missing values
# replace null values with median for children column
df['children'] = df['children'].fillna(df['children'].median())
# replace null values with median for agent column
df['agent'] = df['agent'].fillna(-1)

# %%
df.fillna({'country': 'Unknown'}, inplace=True) # Filling missing country values with 'Unknown'

# %%
df.isnull().sum() #checking for missing values after cleaning
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
#data type handling
# Step 1: Convert 'reservation_status_date' to datetime

df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])


df['arrival_date'] = pd.to_datetime(df['arrival_date_year'].astype(str) + '-' + df['arrival_date_month'] + '-' + df['arrival_date_day_of_month'].astype(str), errors='coerce')

# Step 3: Convert 'adr' column to float (if it was wrongly read as object or string)

df['adr'] = df['adr'].astype(float)

# %%
# Handling Duplicates
df.duplicated().sum()
# Out:
# np.int64(32001)

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking for logical errors i.e. checking if all the three rows including adults, children and baby are 0 at the same time.
# filter data

filter = (df.children == 0) & (df.adults == 0) & (df.babies == 0)
df[filter]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 115029    City Hotel            0        107               2017
# 115091    City Hotel            0          1               2017
# 116251    City Hotel            0         44               2017
# 116534    City Hotel            0          2               2017
# 117087    City Hotel            0        170               2017
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 2224              October                          6                        0
# ...

# %%
#drop rows with logical errors

indexguest = df[(df['children'] == 0) & (df['adults'] == 0) & (df['babies'] == 0)].index
df.drop(indexguest , inplace=True)

#reset index to our new dataset
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
# ...

# %%
#Verifying data consistency
# Check for any invalid booking dates (e.g., 'lead_time' < 0)

df = df[df['lead_time'] >= 0]

# Ensure there are no negative values in 'adr' (average daily rate)

df = df[df['adr'] >= 0]

# Confirm that the dataframe is clean

df.shape
# Out:
# (87222, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87222 entries, 0 to 87222
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87222 non-null  object
#  1   is_canceled                     87222 non-null  int64
#  2   lead_time                       87222 non-null  int64
#  3   arrival_date_year               87222 non-null  int64
#  4   arrival_date_month              87222 non-null  object
#  5   arrival_date_day_of_month       87222 non-null  int64
#  6   stays_in_weekend_nights         87222 non-null  int64
#  7   stays_in_week_nights            87222 non-null  int64
#  8   adults                          87222 non-null  int64
#  9   children                        87222 non-null  float64
#  10  babies                          87222 non-null  int64
#  11  meal                            87222 non-null  object
# ...

# %%
#saving the cleaned file
df.to_csv("/content/sample_data/cleaned_hotel_bookings.csv", index=False)
print("Saved Successfully")
# Out:
# Saved Successfully

# %% [markdown]
# **2. Analytics and Reporting**

# %%
df1= pd.read_csv("/content/sample_data/cleaned_hotel_bookings.csv")
df1['revenue'] = df1['adr'] * (df1['stays_in_weekend_nights'] + df1['stays_in_week_nights'])
df1['arrival_date'] = pd.to_datetime(df1[['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month']].astype(str).agg('-'.join, axis=1), errors='coerce')
monthly_revenue = df1.groupby(df1['arrival_date'].dt.to_period('M'))['revenue'].sum()
monthly_revenue_str_keys = {str(period): value for period, value in monthly_revenue.items()}
cancellation_rate = df1['is_canceled'].mean() * 100
country_counts = df1['country'].value_counts().head(10).to_dict()
lead_time_stats = df1['lead_time'].describe().to_dict()
geo_distribution = df1["country"].value_counts()
popular_hotel_type = df1["hotel"].value_counts().idxmax()

analytics = {
    "monthly_revenue": monthly_revenue_str_keys,
    "cancellation_rate": cancellation_rate,
    "geo_distribution": geo_distribution.to_dict(),
    "lead_time_stats": lead_time_stats,
    "top_countries": country_counts,
    "popular_hotel_type": popular_hotel_type,

}

# %%
# Storing the precomputed insights in json
import json
with open("analytics.json", "w") as f:
    json.dump(analytics, f)
    print("Analytics saved to analytics.json")
# Out:
# Analytics saved to analytics.json

# %% [markdown]
# *Data Visualization*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#revenue trends over time
plt.figure(figsize=(10, 5))
plt.plot(list(monthly_revenue_str_keys.keys()), list(monthly_revenue_str_keys.values()), marker='o', linestyle='--')
plt.xticks(rotation=45)
plt.title("Revenue Trends Over Time ")
plt.xlabel("Month-Year")
plt.ylabel("Total Revenue")
plt.grid(True)
plt.show()

# %%
#booking cancellation rate
plt.figure(figsize=(6, 6))
labels = ["Cancelled", "Not Cancelled"]
sizes = [df["is_canceled"].sum(), len(df) - df["is_canceled"].sum()]
plt.pie(sizes, labels=labels, autopct="%1.1f%%", colors=["red", "cyan"], startangle=90)
plt.title("Booking Cancellation Rate")
plt.show()

# %%
#geographical distributions of bookings
plt.figure(figsize=(12, 6))
top_countries = df["country"].value_counts().head(10)  # Top 10
sns.barplot(x=top_countries.index, y=top_countries.values, palette="coolwarm")
plt.title("Top 10 Countries by Booking Volume")
plt.xlabel("Country")
plt.ylabel("Number of Bookings")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-54-cf751e6cfc86>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.index, y=top_countries.values, palette="coolwarm")

# %%
#booking lead time distribution
plt.figure(figsize=(10, 6))
sns.histplot(df["lead_time"], bins=30, kde=True)
plt.title('Booking Lead Time Distribution')
plt.xlabel('Days before Booking')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#most popular hotel
plt.figure(figsize=(5, 5))
sns.barplot(x=df["hotel"].value_counts().index, y=df["hotel"].value_counts().values, palette="coolwarm")
plt.title("Most Popular Hotel Type")
plt.xlabel("Hotel Type")
plt.ylabel("Number of Bookings")
plt.show()
# Out:
# <ipython-input-56-ff75326bcdb7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["hotel"].value_counts().index, y=df["hotel"].value_counts().values, palette="coolwarm")

# %% [markdown]
# **Retrieval-Augmented Question Answering (RAG)**

# %%
# !pip install sentence-transformers faiss-cpu transformers

# %%
#Using df1 i.e. the cleaned data for further process
# Create a text column to embed – customize based on your dataset
df1['text'] = df1.apply(lambda row: f"Hotel: {row['hotel']}, Country: {row['country']}, Lead Time: {row['lead_time']}, Cancelled: {row['is_canceled']}, Arrival Date: {row['arrival_date_year']}-{row['arrival_date_month']}", axis=1)
# Out:
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<Server.serve() done, defined at /usr/local/lib/python3.11/dist-packages/uvicorn/server.py:68> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/uvicorn/main.py", line 579, in run
#     server.run()
#   File "/usr/local/lib/python3.11/dist-packages/uvicorn/server.py", line 66, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#   File "/usr/local/lib/python3.11/dist-packages/nest_asyncio.py", line 133, in _run_once
#     handle._run()
# ...

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Use a lightweight transformer for embedding
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Encode text into embeddings
text_embeddings = embedding_model.encode(df1['text'].tolist(), convert_to_numpy=True)

# Build FAISS index
index = faiss.IndexFlatL2(text_embeddings.shape[1])
index.add(text_embeddings)

# Save text for retrieval
texts = df1['text'].tolist()

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load FLAN-T5 model and tokenizer
model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
def answer_query_with_rag(question, k=5):
    # Embed the user question
    question_embedding = embedding_model.encode([question])[0]

    # Retrieve top-k similar entries
    _, indices = index.search(np.array([question_embedding]), k)
    retrieved_texts = [texts[i] for i in indices[0]]

    # Create context prompt
    context = " ".join(retrieved_texts)
    prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"

    # Tokenize and generate answer
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512)
    outputs = model.generate(**inputs, max_new_tokens=100)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return answer

# %%
# Ask user
user_query = input("Ask a question about hotel bookings: ")
response = answer_query_with_rag(user_query)
print("\nAnswer:", response)
# Out:
# Ask a question about hotel bookings: which country is the least to book
#
# Answer: NOR

# %%
evaluation_data = [
    {"question": "Which month has most bookings?", "ground_truth": "October"},
    {"question": "Show me the total revenue for July 2017?", "ground_truth": "$247,020"},
    {"question": "Which location has the highest booking cancellation?", "ground_truth": "City Hotel"},
    {"question": "Which country has the least booking?", "ground_truth": "NOR"},
]

# %%
# !pip install sklearn
from sklearn.metrics import f1_score

def evaluate_rag_system(evaluation_data, k=5):
    total_questions = len(evaluation_data)
    correct_answers = 0
    all_generated_answers = []
    all_ground_truths = []

    for item in evaluation_data:
        question = item["question"]
        ground_truth = item["ground_truth"]

        # Get the answer from the RAG system
        generated_answer = answer_query_with_rag(question, k)

        # Store generated and ground truth answers for evaluation
        all_generated_answers.append(generated_answer)
        all_ground_truths.append(ground_truth)

        # Check if the generated answer matches the ground truth
        if generated_answer.strip().lower() == ground_truth.strip().lower():
            correct_answers += 1

    # Calculate Exact Match (EM) and F1 Score
    accuracy = correct_answers / total_questions
    f1 = f1_score(all_ground_truths, all_generated_answers, average='weighted')

    print(f"Accuracy: {accuracy:.2f}")
    print(f"F1 Score: {f1:.2f}")

# Run the evaluation
evaluate_rag_system(evaluation_data)
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Accuracy: 0.25
# F1 Score: 0.25

# %% [markdown]
# **API**

# %%
# !pip install flask flask-cors flask-ngrok pyngrok

# %%
from flask import Flask, request, jsonify
from flask_cors import CORS
from pyngrok import ngrok
import threading

# %%
from pyngrok import ngrok

# Paste your token between the quotes
ngrok.set_auth_token("***********************************************")

# %%
# !pkill -f flask
# !pkill -f ngrok

# %%
from flask import Flask, request, jsonify
from flask_cors import CORS
import threading
import json
from pyngrok import ngrok

# %%
app = Flask(__name__)
CORS(app)
@app.route("/ask", methods=["POST"])
def ask():
    data = request.get_json()
    question = data.get("question", "")
    if not question:
        return jsonify({"error": "Missing 'question' in request body"}), 400
    answer = answer_query_with_rag(question)
    return jsonify({"question": question, "answer": answer})

# Flask route for analytics
@app.route('/analytics', methods=['POST'])
def analytics():
    data = request.get_json()
    print("Analytics Request Received:", data)

    # Example mock analytics response
    response = {
        "most_cancelled_country": "Portugal",
        "highest_avg_price_country": "United Kingdom",
        "peak_booking_month": "August"
    }
    return jsonify(response)

# Run app in thread
def run():
    app.run(port=5001, debug=False)

thread = threading.Thread(target=run)
thread.daemon = True
thread.start()

# !pkill -f ngrok
# ngrok expose
try:
    public_url = ngrok.connect(5001)
    print("Public URL:", public_url)
except Exception as e:
    print(f"Error creating ngrok tunnel: {e}")

# %%
import requests
import json

public_url = "https://0125-35-223-178-30.ngrok-free.app/"  # Replace with the URL printed by the previous cell

# Test /ask endpoint
ask_payload = {"question": "Find bookings from France that were canceled."}
headers = {'Content-Type': 'application/json'}
try:
    ask_response = requests.post(f"{public_url}/ask", headers=headers, data=json.dumps(ask_payload))
    ask_response.raise_for_status()
    ask_data = ask_response.json()
    print("--- /ask Response ---")
    print(json.dumps(ask_data, indent=4))
except requests.exceptions.RequestException as e:
    print(f"Error calling /ask: {e}")

# Test /analytics endpoint
analytics_payload = {}
try:
    analytics_url = f"{public_url}/analytics"
    analytics_response = requests.post(analytics_url, headers=headers, data=json.dumps(analytics_payload))
    analytics_response.raise_for_status()
    analytics_data = analytics_response.json()
    print("\n--- /analytics Response ---")
    print(json.dumps(analytics_data, indent=4))
except requests.exceptions.RequestException as e:
    print(f"Error calling /analytics: {e}")
